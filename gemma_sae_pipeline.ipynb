# %% [markdown]
# # Gemma‑2 + SAE (sae‑lens) — Document Feature Extraction
# This notebook walks you step‑by‑step through loading **Gemma‑2 9B**, attaching a **SAE** from `sae_lens`, gathering residual activations at a target layer, and producing per‑document feature vectors (sum/mean/max across tokens).
# It also reconstructs documents from chunked JSONL rows and aligns them with metadata for downstream tasks.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.26 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas>=2.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.3.2)
# Requirement already satisfied: torch>=2.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2.8.0)
# Requirement already satisfied: transformers>=4.50 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (4.56.1)
# Requirement already satisfied: huggingface_hub>=0.23 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.34.4)
# Requirement already satisfied: sae-lens>=6.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (6.12.1)
# Requirement already satisfied: sentencepiece>=0.1.99 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: ipywidgets in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: filelock in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (3.5)
# Requirement already satisfied: jinja2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from torch>=2.3->-r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from triton==3.4.0->torch>=2.3->-r requirements.txt (line 5)) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: requests in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformers>=4.50->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from huggingface_hub>=0.23->-r requirements.txt (line 7)) (1.1.9)
# Requirement already satisfied: babe<0.0.8,>=0.0.7 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (0.0.7)
# Requirement already satisfied: datasets>=3.1.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (3.9.1)
# Requirement already satisfied: plotly>=5.19.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (6.3.0)
# Requirement already satisfied: plotly-express>=0.4.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: python-dotenv>=1.0.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: simple-parsing<0.2.0,>=0.1.6 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: tenacity>=9.0.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (9.1.2)
# Requirement already satisfied: transformer-lens<3.0.0,>=2.16.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sae-lens>=6.0->-r requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: comm>=0.1.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 11)) (9.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 11)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 11)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 11)) (3.0.15)
# Requirement already satisfied: py2store in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.21)
# Requirement already satisfied: graze in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.31)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: xxhash in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (0.70.16)
# Requirement already satisfied: decorator in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: stack_data in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.6.3)
# Requirement already satisfied: click in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens>=6.0->-r requirements.txt (line 8)) (8.2.1)
# Requirement already satisfied: joblib in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens>=6.0->-r requirements.txt (line 8)) (1.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from plotly>=5.19.0->sae-lens>=6.0->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from plotly-express>=0.4.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.14.5)
# Requirement already satisfied: scipy>=0.18 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from plotly-express>=0.4.1->sae-lens>=6.0->-r requirements.txt (line 8)) (1.16.2)
# Requirement already satisfied: patsy>=0.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from plotly-express>=0.4.1->sae-lens>=6.0->-r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from requests->transformers>=4.50->-r requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from requests->transformers>=4.50->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from requests->transformers>=4.50->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from requests->transformers>=4.50->-r requirements.txt (line 6)) (2025.8.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from simple-parsing<0.2.0,>=0.1.6->sae-lens>=6.0->-r requirements.txt (line 8)) (0.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.3->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (1.10.1)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.0.3)
# Requirement already satisfied: einops>=0.6.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: rich>=12.6.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (14.1.0)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (4.4.4)
# Requirement already satisfied: wandb>=0.13.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.21.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from jinja2->torch>=2.3->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: psutil in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (7.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (3.12.15)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from jaxtyping>=0.2.11->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from rich>=12.6.0->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (3.1.45)
# Requirement already satisfied: platformdirs in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (4.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (6.32.1)
# Requirement already satisfied: pydantic<3 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (2.37.1)
# Requirement already satisfied: dol in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from graze->babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (0.3.20)
# Requirement already satisfied: config2py in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.38)
# Requirement already satisfied: importlib_resources in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (6.5.2)
# Requirement already satisfied: executing>=1.2.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens>=6.0->-r requirements.txt (line 8)) (1.20.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: i2 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from config2py->py2store->babe<0.0.8,>=0.0.7->sae-lens>=6.0->-r requirements.txt (line 8)) (0.1.48)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens>=6.0->-r requirements.txt (line 8)) (5.0.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 0 — Prerequisites
# - **Hardware:** A CUDA‑capable GPU is strongly recommended (Gemma‑2 9B is large).
# - **Python:** 3.9+
# - **Accounts:** Access to the gated Hugging Face models if required (e.g., Gemma).
# - **Auth:** Set your Hugging Face token in the environment variable `HF_HUB_TOKEN`.
#
# > If you don't have access to `google/gemma-2-9b` or a sufficiently large GPU, consider swapping in a smaller model and a matching SAE release.

# %%
# (Optional) Install dependencies in your environment
# If you're running locally and need to install packages, uncomment these lines.
# Note: Some installs require system CUDA toolkits preconfigured.
# !pip install -U 'transformers>=4.44' 'torch' 'huggingface_hub' 'pandas' 'numpy' 'sae-lens'

# %% [markdown]
# ## Step 1 — Imports, device, and logging
# We configure a single‑device setup (CUDA if available), set up logging to both file and console, and disable gradients for inference‑only execution.

# %%
import os
import json
import numpy as np
import pandas as pd
import logging
import torch
import torch.nn as nn

# force huggingface download path
# DO NOT CHANGE THIS CELL
# RUN THIS CELL ONLY IF RUNNING ON PACE-ICE

# override the huggingface cache path and nltk cache path
dirs = {
    "HF_HOME":"~/scratch/hf_cache",
    "TRITON_CACHE_DIR":"~/scratch/triton_cache",
    "TORCHINDUCTOR_CACHE_DIR":"~/scratch/inductor_cache",
    'NLTK_DATA':"~/scratch/nltk_data"
}

for name in dirs:
    d = dirs[name]
    path = os.path.expanduser(d)
    print(name)
    print(path)
    os.makedirs(path, exist_ok=True)
    # making sure the cache dirs are rwx for owner
    os.chmod(path, 0o700)
    os.environ[name] = path





# os.environ["HF_HUB_TOKEN"] = ""

# --- Read token from secret.txt ---
try:
    with open("secret.txt", "r") as f:
        token = f.read().strip()
        os.environ["HF_HUB_TOKEN"] = token
except FileNotFoundError:
    print("❌ Error: secret.txt not found. Please create it and add your Hugging Face token.")
    exit() # Exit the script if the token file is missing

from sae_lens import SAE
from transformers import AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import login
login(token=os.getenv("HF_HUB_TOKEN"))

# ——— 1. Single device definition ———
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

logging.basicConfig(
    filename="doc_processing.log",
    filemode="w",
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)
logger = logging.getLogger(__name__)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
console.setFormatter(logging.Formatter("%(levelname)s: %(message)s"))
logging.getLogger().addHandler(console)

# === Login & model setup ===
torch.set_grad_enabled(False)
hf_token = os.getenv("HF_HUB_TOKEN")
if hf_token is None:
    logger.warning("HF_HUB_TOKEN is not set; private/gated models may fail to load.")
# Out:
# HF_HOME
# /home/hice1/mzhang754/scratch/hf_cache
# TRITON_CACHE_DIR
# /home/hice1/mzhang754/scratch/triton_cache
# TORCHINDUCTOR_CACHE_DIR
# /home/hice1/mzhang754/scratch/inductor_cache
# NLTK_DATA
# /home/hice1/mzhang754/scratch/nltk_data
# Using device: cuda:0

# %% [markdown]
# ## Step 2 — Load model & tokenizer, then move to device
# This uses `google/gemma-2-9b`. If you do not have access or sufficient VRAM, substitute with a smaller model (and a compatible SAE release).

# %%
# ——— 2. Load model + tokenizer, then send to device ———
# Note: 'use_auth_token' may be deprecated in newer transformers versions; if so, replace with 'token=hf_token'.
model = AutoModelForCausalLM.from_pretrained(
    # uncomment below if use Gemma-2 2B
    # "google/gemma-2-2b",
    # uncomment below if use Gemma-2 9B
    "google/gemma-2-9b",
    use_auth_token=hf_token
).to(device)

tokenizer = AutoTokenizer.from_pretrained(
    # uncomment below if use Gemma-2 2B
    # "google/gemma-2-2b",
    # uncomment below if use Gemma-2 9B
    "google/gemma-2-9b",
    use_auth_token=hf_token
)

# Load the SAE that matches Gemma‑2 model
sae, _, _ = SAE.from_pretrained(
    # uncomment below if use Gemma-2 2B
    # release="gemma-scope-2b-pt-res-canonical",
    # uncomment below if use Gemma-2 9B
    release="gemma-scope-9b-pt-res-canonical",

    # uncomment below if use Gemma-2 2B
    # sae_id="layer_12/width_16k/canonical",
    # uncomment below if use Gemma-2 9B
    sae_id="layer_20/width_131k/canonical",

    device="cuda" if torch.cuda.is_available() else "cpu",
)

model.eval()
sae.eval()
# Out:
# /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:492: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/856 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/2.38G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/4.84G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:1010: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# layer_20/width_131k/average_l0_114/param(…):   0%|          | 0.00/3.76G [00:00<?, ?B/s]
# /home/hice1/mzhang754/scratch/surprise-sae-starter/venv/lib/python3.11/site-packages/sae_lens/saes/sae.py:249: UserWarning:
# This SAE has non-empty model_from_pretrained_kwargs.
# For optimal performance, load the model like so:
# model = HookedSAETransformer.from_pretrained_no_processing(..., **cfg.model_from_pretrained_kwargs)
#   warnings.warn(
# /tmp/ipykernel_1679037/1056346135.py:20: DeprecationWarning: Unpacking SAE objects is deprecated. SAE.from_pretrained() now returns only the SAE object. Use SAE.from_pretrained_with_cfg_and_sparsity() to get the config dict and sparsity as well.
#   sae, _, _ = SAE.from_pretrained(
# JumpReLUSAE(
#   (activation_fn): ReLU()
#   (hook_sae_input): HookPoint()
#   (hook_sae_acts_pre): HookPoint()
#   (hook_sae_acts_post): HookPoint()
#   (hook_sae_output): HookPoint()
#   (hook_sae_recons): HookPoint()
#   (hook_sae_error): HookPoint()
# )

# %% [markdown]
# ### (Optional) Step 2b — Load SAE weights manually
# If you prefer to download SAE params yourself and define a simple JumpReLU SAE, use the template below instead of the `SAE.from_pretrained(...)` snippet. This is provided as a commented reference.

# %%
# # ——— 3. Download SAE params and move to device ———
# path_to_params = hf_hub_download(
#     repo_id="google/gemma-scope-9b-pt-res",
#     filename="layer_20/width_16k/average_l0_68/params.npz",
#     use_auth_token=hf_token
# )
# params = np.load(path_to_params)
# pt_params = {k: torch.from_numpy(v).to(device) for k, v in params.items()}

# # Define the SAE module
# class JumpReLUSAE(nn.Module):
#     def __init__(self, d_model, d_sae):
#         super().__init__()
#         self.W_enc = nn.Parameter(torch.zeros(d_model, d_sae))
#         self.W_dec = nn.Parameter(torch.zeros(d_sae, d_model))
#         self.threshold = nn.Parameter(torch.zeros(d_sae))
#         self.b_enc = nn.Parameter(torch.zeros(d_sae))
#         self.b_dec = nn.Parameter(torch.zeros(d_model))

#     def encode(self, input_acts):
#         pre_acts = input_acts @ self.W_enc + self.b_enc
#         mask = pre_acts > self.threshold
#         return mask * torch.nn.functional.relu(pre_acts)

#     def decode(self, acts):
#         return acts @ self.W_dec + self.b_dec

#     def forward(self, acts):
#         return self.decode(self.encode(acts))

# sae = JumpReLUSAE(
#     d_model=params["W_enc"].shape[0],
#     d_sae=params["W_enc"].shape[1]
# ).to(device)
# sae.load_state_dict(pt_params)

# %% [markdown]
# ## Step 3 — Gather residual activations at a target layer
# We register a forward hook on the chosen layer (here, `layer_20`) and capture the residual stream activations for the current inputs.

# %%
def gather_residual_activations(model, target_layer, inputs):
    target_act = None
    def gather_target_act_hook(mod, inputs, outputs):
        nonlocal target_act
        target_act = outputs[0]
        return outputs
    handle = model.model.layers[target_layer].register_forward_hook(gather_target_act_hook)
    _ = model.forward(inputs)
    handle.remove()
    return target_act

# %% [markdown]
# ## Step 4 — Define data locations
# Set the input/output paths and list the JSONL + metadata files to process.

# %%
# File lists
jsonl_files = [
    "transcript_componenttext_2012_1.jsonl",
    "transcript_componenttext_2012_2.jsonl",
    # "transcript_componenttext_2013_1.jsonl",
    # "transcript_componenttext_2013_2.jsonl",
    # "transcript_componenttext_2014_1.jsonl",
    # "transcript_componenttext_2014_2.jsonl",
]
meta_files = [
    "transcript_metadata_2012_1.csv",
    "transcript_metadata_2012_2.csv",
    # "transcript_metadata_2013_1.csv",
    # "transcript_metadata_2013_2.csv",
    # "transcript_metadata_2014_1.csv",
    # "transcript_metadata_2014_2.csv",
]
input_dir = "./data/train_test_data"
jsonl_files = [os.path.join(input_dir, fn) for fn in jsonl_files]
meta_files = [os.path.join(input_dir, fn) for fn in meta_files]

# uncomment below if use Gemma-2 2B
# output_dir = "./data/doc_features/2b_canonical_16k"
# uncomment below if use Gemma-2 9B
output_dir = "./data/doc_features/9b_canonical_131k

os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Step 5 — Reconstruct documents from chunked JSONL
# Each JSONL row contains a mapping from chunk keys to text. We group by `transcriptid` and order by the embedded chunk index to rebuild the full document.

# %%
def process_jsonl(path):
    temp = {}
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            obj = json.loads(line)
            for key, text in obj.items():
                parts = key.split("_")
                tid, order = parts[2], int(parts[3])
                temp.setdefault(tid, []).append((order, text))
    return {
        tid: "\n".join(str(txt) for _, txt in sorted(lst, key=lambda x: x[0]))
        for tid, lst in temp.items()
    }

# %% [markdown]
# ## Step 6 — Run feature extraction
# For each transcript:
# 1. Tokenize (truncate to 20k tokens).
# 2. Capture residual activations at `layer_20`.
# 3. Encode with the SAE.
# 4. Aggregate features across tokens (`sum`, `mean`, `max`).
# 5. Periodically flush to disk in `.npz` and write aligned metadata in `.csv`.

# %%
# Main processing
for jpath, mpath in zip(jsonl_files, meta_files):
    prefix = os.path.splitext(os.path.basename(jpath))[0]
    logger.info(f"Starting processing for {prefix}")

    # load & align metadata once per file
    meta = pd.read_csv(mpath, dtype={"transcriptid": str})
    meta_unique = (
        meta[["transcriptid", "SUESCORE"]]
        .drop_duplicates(subset="transcriptid", keep="first")
        .set_index("transcriptid")
    )

    try:
        docs = process_jsonl(jpath)
        tids = list(docs.keys())

        # initialize buffers & counter
        feats_mean, feats_max = [], []
        feats_sum = []
        feats_ntokens = []
        success_tids = []
        count = 0

        for tid in tids[:]:
            logger.info(f"processing tid: {tid}")
            try:
                text = docs[tid]
                # tokenize & truncate to 20k tokens
                inputs = tokenizer(
                    text,
                    return_tensors="pt",
                    add_special_tokens=True,
                    truncation=True,
                    max_length=20000,
                ).input_ids.to(device)

                # record token count
                ntok = inputs.size(1)
                feats_ntokens.append(ntok)

                # get activations & SAE encodings
                res_act = gather_residual_activations(model, 20, inputs)
                acts = sae.encode(res_act.float()).cpu().numpy().squeeze(0)

                # compute feature vectors
                sum_vec  = acts.sum(axis=0)
                mean_vec = acts.mean(axis=0)
                max_vec  = acts.max(axis=0)

                feats_sum.append(sum_vec)
                feats_mean.append(mean_vec)
                feats_max.append(max_vec)
                success_tids.append(tid)

            except Exception as e:
                logger.exception(f"Doc {tid} failed: {e}")

            finally:
                # free per-doc GPU memory
                for var in ("inputs", "res_act", "acts"):
                    if var in locals():
                        del locals()[var]
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()

                # increment & maybe flush
                count += 1
                if count % 100 == 0:
                    part = count // 100
                    logger.info(f"Flushing part {part} ({count} docs)")
                    # stack features
                    # uncomment below if use Gemma-2 2B
                    npz_path = os.path.join(output_dir, f"{prefix}_part{part}_2b_canon_features.npz")
                    # uncomment below if use Gemma-2 9B
                    # npz_path = os.path.join(output_dir, f"{prefix}_part{part}_9b_canon_features.npz")
                    np.savez(
                        npz_path,
                        X_sum        = np.vstack(feats_sum),
                        X_mean       = np.vstack(feats_mean),
                        X_max        = np.vstack(feats_max),
                        token_counts = np.array(feats_ntokens, int),
                        transcriptids = np.array(success_tids, dtype=str)
                    )
                    # write meta CSV
                    meta_batch = (
                        meta_unique
                        .reindex(success_tids)
                        .reset_index()
                    )
                    meta_batch["SUESCORE"] = meta_batch["SUESCORE"].astype(float)
                    meta_batch["label"] = meta_batch["SUESCORE"].apply(
                        lambda s: 1 if s >= 0.5 else (0 if s <= -0.5 else np.nan)
                    )
                    meta_batch.to_csv(
                        # uncomment below if use Gemma-2 2B
                        # os.path.join(output_dir, f"{prefix}_part{part}_2b_canon_features_meta.csv"),
                        # uncomment below if use Gemma-2 9B
                        os.path.join(output_dir, f"{prefix}_part{part}_9b_canon_features_meta.csv"),
                        index=False
                    )
                    # clear buffers
                    feats_sum.clear()
                    feats_mean.clear()
                    feats_max.clear()
                    feats_ntokens.clear()
                    success_tids.clear()
                    if torch.cuda.is_available():
                        torch.cuda.empty_cache()

        # final flush for any remainder
        if count % 100 != 0:
            part = (count // 100) + 1
            logger.info(f"Flushing final part {part} ({count % 100} docs)")
            np.savez(
                # uncomment below if use Gemma-2 2B
                # os.path.join(output_dir, f"{prefix}_part{part}_2b_canon_features.npz"),
                # uncomment below if use Gemma-2 9B
                os.path.join(output_dir, f"{prefix}_part{part}_9b_canon_features.npz"),
                X_sum        = np.vstack(feats_sum),
                X_mean       = np.vstack(feats_mean),
                X_max        = np.vstack(feats_max),
                token_counts = np.array(feats_ntokens, int),
                transcriptids = np.array(success_tids, dtype=str)
            )
            meta_batch = (
                meta_unique
                .reindex(success_tids)
                .reset_index()
            )
            meta_batch["SUESCORE"] = meta_batch["SUESCORE"].astype(float)
            meta_batch["label"] = meta_batch["SUESCORE"].apply(
                lambda s: 1 if s >= 0.5 else (0 if s <= -0.5 else np.nan)
            )
            meta_batch.to_csv(
                # uncomment below if use Gemma-2 2B
                # os.path.join(output_dir, f"{prefix}_part{part}_2b_canon_features_meta.csv"),
                # uncomment below if use Gemma-2 9B
                os.path.join(output_dir, f"{prefix}_part{part}_9b_canon_features_meta.csv"),
                index=False
            )

        logger.info(f"Finished processing & flushing all parts for {prefix}")

    except Exception as e:
        logger.exception(f"Failed to process {prefix}: {e}")
# Out:
# INFO: Starting processing for transcript_componenttext_2014_1
# INFO: processing tid: 564725
# INFO: processing tid: 564749
# INFO: processing tid: 564875
# INFO: processing tid: 564953
# INFO: processing tid: 565016
# INFO: processing tid: 565036
# INFO: processing tid: 565105
# INFO: processing tid: 565122
# INFO: processing tid: 565139
# INFO: processing tid: 565161
# INFO: processing tid: 565168
# INFO: processing tid: 565178
# INFO: processing tid: 565214
# INFO: processing tid: 565220
# INFO: processing tid: 565279
# INFO: processing tid: 565299
# INFO: processing tid: 565337
# INFO: processing tid: 565351
# INFO: processing tid: 565355
# INFO: processing tid: 565384
# INFO: processing tid: 565393
# INFO: processing tid: 565404
# INFO: processing tid: 565411
# INFO: processing tid: 565429
# INFO: processing tid: 565441
# INFO: processing tid: 565461
# INFO: processing tid: 565510
# INFO: processing tid: 565606
# INFO: processing tid: 565624
# INFO: processing tid: 565632
# INFO: processing tid: 565634
# INFO: processing tid: 565646
# INFO: processing tid: 565667
# INFO: processing tid: 565684
# INFO: processing tid: 565785
# INFO: processing tid: 565795
# INFO: processing tid: 565816
# INFO: processing tid: 565880
# INFO: processing tid: 565891
# INFO: processing tid: 565989
# INFO: processing tid: 565992
# INFO: processing tid: 566193
# INFO: processing tid: 566439
# INFO: processing tid: 566444
# INFO: processing tid: 566457
# INFO: processing tid: 566580
# INFO: processing tid: 566584
# INFO: processing tid: 566614
# INFO: processing tid: 566667
# INFO: processing tid: 566691
# INFO: processing tid: 566697
# INFO: processing tid: 566719
# INFO: processing tid: 566727
# INFO: processing tid: 566730
# INFO: processing tid: 566733
# INFO: processing tid: 566765
# INFO: processing tid: 566876
# INFO: processing tid: 566894
# INFO: processing tid: 566907
# INFO: processing tid: 566924
# INFO: processing tid: 566955
# INFO: processing tid: 566962
# INFO: processing tid: 566963
# INFO: processing tid: 730125
# INFO: processing tid: 730144
# INFO: processing tid: 730158
# INFO: processing tid: 730168
# INFO: processing tid: 730169
# INFO: processing tid: 730178
# INFO: processing tid: 730193
# INFO: processing tid: 730205
# INFO: processing tid: 730209
# INFO: processing tid: 730213
# INFO: processing tid: 730234
# INFO: processing tid: 730237
# INFO: processing tid: 730239
# INFO: processing tid: 730297
# INFO: processing tid: 730298
# INFO: processing tid: 730318
# INFO: processing tid: 730319
# INFO: processing tid: 730320
# INFO: processing tid: 730344
# INFO: processing tid: 730506
# INFO: processing tid: 730522
# INFO: processing tid: 730535
# INFO: processing tid: 730618
# INFO: processing tid: 730638
# INFO: processing tid: 730667
# INFO: processing tid: 730842
# INFO: processing tid: 731015
# INFO: processing tid: 731090
# INFO: processing tid: 731145
# INFO: processing tid: 731395
# INFO: processing tid: 731452
# INFO: processing tid: 731462
# INFO: processing tid: 731481
# INFO: processing tid: 731519
# INFO: processing tid: 731524
# INFO: processing tid: 731783
# INFO: processing tid: 731814
# INFO: processing tid: 731880
# INFO: processing tid: 731887
# INFO: processing tid: 731978
# INFO: processing tid: 732001
# INFO: processing tid: 732015
# INFO: processing tid: 732135
# INFO: processing tid: 732141
# INFO: processing tid: 732145
# INFO: processing tid: 732150
# INFO: processing tid: 732157
# INFO: processing tid: 732217
# INFO: processing tid: 732250
# INFO: processing tid: 732264
# INFO: processing tid: 732271
# INFO: processing tid: 732290
# INFO: processing tid: 732295
# INFO: processing tid: 732320
# INFO: processing tid: 732351
# INFO: processing tid: 732367
# INFO: processing tid: 732387
# INFO: processing tid: 732411
# INFO: processing tid: 732418
# INFO: processing tid: 732509
# INFO: processing tid: 732520
# INFO: processing tid: 732530
# INFO: processing tid: 732566
# INFO: processing tid: 732620
# INFO: processing tid: 732711
# INFO: processing tid: 732715
# INFO: processing tid: 732728
# INFO: processing tid: 732737
# INFO: processing tid: 732748
# INFO: processing tid: 732778
# INFO: processing tid: 732789
# INFO: processing tid: 732799
# INFO: processing tid: 732800
# INFO: processing tid: 732807
# INFO: processing tid: 732818
# INFO: processing tid: 732831
# INFO: processing tid: 732832
# INFO: processing tid: 732846
# INFO: processing tid: 732862
# INFO: processing tid: 732883
# INFO: processing tid: 732905
# INFO: processing tid: 732907
# INFO: processing tid: 732916
# INFO: processing tid: 732959
# INFO: processing tid: 732968
# INFO: processing tid: 732983
# INFO: processing tid: 732995
# INFO: processing tid: 733010
# INFO: processing tid: 733013
# INFO: processing tid: 733059
# INFO: processing tid: 733079
# INFO: processing tid: 733090
# INFO: processing tid: 733096
# INFO: processing tid: 733112
# INFO: processing tid: 733152
# INFO: processing tid: 733204
# INFO: processing tid: 733259
# INFO: processing tid: 733267
# INFO: Flushing part 13 (1300 docs)
# INFO: processing tid: 733412
# INFO: processing tid: 733516
# INFO: processing tid: 733539
# INFO: processing tid: 733590
# INFO: processing tid: 733642
# INFO: processing tid: 733661
# INFO: processing tid: 733677
# INFO: processing tid: 733679
# INFO: processing tid: 733700
# INFO: processing tid: 733806
# INFO: processing tid: 733836
# INFO: processing tid: 733881
# INFO: processing tid: 733929
# INFO: processing tid: 733989
# INFO: processing tid: 734044
# INFO: processing tid: 734119
# INFO: processing tid: 734137
# INFO: processing tid: 734183
# INFO: processing tid: 734193
# INFO: processing tid: 734196
# INFO: processing tid: 734204
# INFO: processing tid: 734369
# INFO: processing tid: 734375
# INFO: processing tid: 734395
# INFO: processing tid: 734448
# INFO: processing tid: 734547
# INFO: processing tid: 734925
# INFO: processing tid: 734956
# INFO: processing tid: 735058
# INFO: processing tid: 735078
# INFO: processing tid: 735082
# INFO: processing tid: 735094
# INFO: processing tid: 735132
# INFO: processing tid: 735194
# INFO: processing tid: 735275
# INFO: processing tid: 735398
# INFO: processing tid: 735405
# INFO: processing tid: 735562
# INFO: processing tid: 736414
# INFO: processing tid: 736458
# INFO: processing tid: 736487
# INFO: processing tid: 736997
# INFO: processing tid: 737196
# INFO: processing tid: 737282
# INFO: processing tid: 737325
# INFO: processing tid: 737428
# INFO: processing tid: 737528
# INFO: processing tid: 737571
# INFO: processing tid: 737757
# INFO: processing tid: 737813
# INFO: processing tid: 737853
# INFO: processing tid: 737854
# INFO: processing tid: 738203
# INFO: processing tid: 738217
# INFO: processing tid: 738301
# INFO: processing tid: 738325
# INFO: processing tid: 738988
# INFO: processing tid: 739025
# INFO: processing tid: 739072
# INFO: processing tid: 739158
# INFO: processing tid: 739210
# INFO: processing tid: 739486
# INFO: processing tid: 739576
# INFO: processing tid: 739640
# INFO: processing tid: 740064
# INFO: processing tid: 740256
# INFO: processing tid: 740266
# INFO: processing tid: 740358
# INFO: processing tid: 740672
# INFO: processing tid: 740691
# INFO: processing tid: 741007
# INFO: processing tid: 741015
# INFO: processing tid: 741302
# INFO: processing tid: 741723
# INFO: processing tid: 741821
# INFO: processing tid: 741897
# INFO: processing tid: 741978
# INFO: processing tid: 741982
# INFO: processing tid: 742076
# INFO: processing tid: 742085
# INFO: processing tid: 742087
# INFO: processing tid: 742265
# INFO: processing tid: 742269
# INFO: processing tid: 742270
# INFO: processing tid: 742366
# INFO: processing tid: 742383
# INFO: processing tid: 742386
# INFO: processing tid: 742535
# INFO: processing tid: 763329
# INFO: Flushing final part 14 (89 docs)
# INFO: Finished processing & flushing all parts for transcript_componenttext_2014_2

# %%
output_dir
# Out:
# './data/doc_features/2b_canonical_16k'

# %% [markdown]
# ## Step 7 — Inspect outputs (optional)
# Quickly list what was saved and preview shapes from an `.npz` file.

# %%
from glob import glob
saved = sorted(glob(os.path.join(output_dir, "*.npz")))
print("Saved NPZ files:", saved[:5], ("... ({} total)".format(len(saved)) if len(saved) > 5 else ""))

if saved:
    sample = np.load(saved[0])
    for k in sample.files:
        print(k, sample[k].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from glob import glob
# ----> 2 saved = sorted(glob(os.path.join(output_dir, "*.npz")))
#       3 print("Saved NPZ files:", saved[:5], ("... ({} total)".format(len(saved)) if len(saved) > 5 else ""))
#       5 if saved:
#
# NameError: name 'os' is not defined
